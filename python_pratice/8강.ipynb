# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('example')
df
# Csv 파일을 읽는 메소드: read_csv(‘파일명’)
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('example1',index=False)

# %%
pd.read_excel('Excel_Sample.xlsx','Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('Excel_Sample1.xlsx',sheet_name='Sheet1')

# %%
df = pd.read_csv("example")
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel("example.xlsx")

# %%
pd.read_excel('Excel_Sample.xlsx','Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('Excel_Sample')

# %%
df = pd.read_csv('Excel_Sample')

# %%
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ## input 은 읽는 파일을 주피터 노트북에 사용할 수 있게 하는것
# ## output은 주피터 노트북에서 그 폴더 안에 파일을 저장하는것

# %%
import matplotlib.pyplot as plt
from unicodedata import normalize
table_MN = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
table_MN
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nickname(s): Land of 10,000 Lakes;North Star S...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                      Largest metro and urban areas
#  12                                         Government
#  13                                         • Governor
#  14                              • Lieutenant Governor
#  15                                        Legislature
# ...

# %%
table_MN[0]
# Out:
#                                             Minnesota  \
# 0                                               State
# 1   .mw-parser-output .ib-settlement-cols{text-ali...
# 2   Nickname(s): Land of 10,000 Lakes;North Star S...
# 3   Motto: L'Étoile du Nord (French: The Star of t...
# 4                           Anthem: "Hail! Minnesota"
# 5   Map of the United States with Minnesota highli...
# 6                                             Country
# 7                                    Before statehood
# 8                               Admitted to the Union
# 9                                             Capital
# 10                                       Largest city
# 11                      Largest metro and urban areas
# 12                                         Government
# 13                                         • Governor
# 14                              • Lieutenant Governor
# 15                                        Legislature
# ...

# %%
table_MN[1]
# Out:
#                    List of state symbols  \
#                          Living insignia
# 0                                   Bird
# 1                              Butterfly
# 2                                   Fish
# 3                                 Flower
# 4                               Mushroom
# 5                                   Tree
# 6                     Inanimate insignia
# 7                               Beverage
# 8                                   Food
# 9                               Gemstone
# 10                                 Other
# 11                         State quarter
# 12                      Released in 2005
# 13  Lists of United States state symbols
#
#
#                                     Living insignia.1
# 0                                         Common loon
# 1                                             Monarch
# 2                                             Walleye
# 3                       Pink-and-white lady's slipper
# ...

# %%
table_MN[2]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21
